# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Buổi 7

# %%
#Câu 1
lst2 = []
for x in range(1,13):
    if x % 2 == 0:
        lst2.append(x)   
print(lst2)
# Out:
# [2, 4, 6, 8, 10, 12]

# %%
#Câu 2
for x in lst2:
    if x % 3 == 0:
        lst2.remove(x)
print(lst2)
# Out:
# [2, 4, 8, 10]

# %%
#Câu 3
lst4 = lst2 + [1, 2, 3]
print(lst4)

lst5 = lst4[:3] + [6, 7, 8] + lst4[3:]
print(lst5)
# Out:
# [2, 4, 8, 10, 1, 2, 3]
# [2, 4, 8, 6, 7, 8, 10, 1, 2, 3]

# %%
#Câu 4
lst6=[]
for x in lst5:
    if x%2 == 0 or x%5 == 0:
        x = 0
    lst6.append(x)
print(lst6)
# Out:
# [0, 0, 0, 0, 7, 0, 0, 1, 0, 3]

# %%
#value = 6
#position = 3

#for x in range(3):
    #lst4.insert(position, value)
    #value +=1
    #position +=1

#print(lst4)

# %%
#for index, item in enumerate(lst5):
    #if item%2 == 0 or item%5 == 0:
        #lst5[index] = 0
        
#print(lst5)
